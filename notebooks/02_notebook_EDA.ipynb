# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from bootcampviztools import pinta_distribucion_categoricas, plot_categorical_relationship_fin, plot_categorical_numerical_relationship, tricategorical_analysis

# %%
train = pd.read_csv("../data/Raw/train_data_raw.csv")
train.head()
# Out:
#   PetType     Breed  Color    Size   WeightKg  Vaccinated  HealthCondition  \
# 0     Cat   Siamese  White   Large   7.489573           0                0
# 1    Bird  Parakeet  White  Medium  23.903091           1                0
# 2     Dog    Poodle   Gray   Large  26.039470           1                0
# 3     Cat   Persian  White   Large  17.110227           0                0
# 4     Cat   Siamese  White  Medium  10.598766           1                0
#
#    TimeInShelterDays  AdoptionFee  PreviousOwner  target  AgeYears
# 0                 70          476              0       0     14.33
# 1                 85          437              0       0     12.33
# 2                 52          451              0       0      7.75
# 3                  6          298              0       0      8.83
# 4                 27           10              0       1      7.42

# %% [markdown]
# ***

# %% [markdown]
# ### Visualización de variable target

# %%
sns.countplot(data = train, x = "target", stat = "percent")
plt.show();

# %% [markdown]
# - Variable binaria
# - No adoptados --> 0
# - Adoptados --> 1
#
# Distribución: Se observa una mayor proporción de animales no adoptados frente a los que han sido adoptados (desbalanceada)

# %% [markdown]
# ***

# %% [markdown]
# ### Correlación de variables categóricas con variable target

# %% [markdown]
# Hipótesis H0 -> No están relacionadas entre sí
#
# Hipótesis H1 -> Están relacionadas
#
# Para todas las variables!!!

# %%
plot_categorical_relationship_fin(train, "target", "PetType")

# %%
tabla_contingencia = pd.crosstab(train['target'], train['PetType'])

from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)


print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 61.94812350233374
#
# P-Value: 2.2539189148478366e-13
#
# Grados de Libertad: 3

# %% [markdown]
# p-value <<<<< 0.05, se acepta H1 --> Relación estadísticamente significativa

# %% [markdown]
# ***

# %%
plot_categorical_relationship_fin(train, "target", "Breed")

# %%
tabla_contingencia = pd.crosstab(train['target'], train['Breed'])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)


print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 135.81989549701333
#
# P-Value: 7.633254108632181e-27
#
# Grados de Libertad: 6

# %% [markdown]
# p-value <<<<< 0.05, se acepta H1 --> Relación estadísticamente significativa

# %% [markdown]
# ***

# %%
plot_categorical_relationship_fin(train, "target", "Color")

# %%
tabla_contingencia = pd.crosstab(train['target'], train['Color'])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)


print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 5.556404248155564
#
# P-Value: 0.23481581076304642
#
# Grados de Libertad: 4

# %% [markdown]
# Las diferencias entre colores dentro de cada categoría de adopción no parecen muy grandes, y eso suele indicar que no hay una relación fuerte entre el color del pelaje y la probabilidad de adopción.
#
# - Patrones parecidos entre adoptados y no adoptados
# - No hay un color que destaque como mucho más adoptado o mucho menos adoptado
# - Se observa que las columnas de color de pelaje, muestran el número de individuos de cada columna, no la adopción.
#
# Queda confirmado por el p-value obtenido (p-value >>>>>> 0.05, no se puede rechazar H0)

# %% [markdown]
# ***

# %%
plot_categorical_relationship_fin(train, "target", "Size")

# %%
tabla_contingencia = pd.crosstab(train['target'], train['Size'])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)


print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 336.95265736356305
#
# P-Value: 6.7867229742694294e-74
#
# Grados de Libertad: 2

# %% [markdown]
# p-value <<<<< 0.05, se acepta H1 --> Relación estadísticamente significativa

# %%
plot_categorical_relationship_fin(train, "target", "Vaccinated")

# %%
tabla_contingencia = pd.crosstab(train['target'], train['Vaccinated'])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)


print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 145.3255122323071
#
# P-Value: 1.8230409680677976e-33
#
# Grados de Libertad: 1

# %% [markdown]
# En este caso, también se está realizando un conteo de los animales no adoptados (vacunados o no) y los no adoptados (vacunados o no):
#
# - En no adoptados hay muchos más vacunados que no vacunados (lo cual no tiene mucho sentido)
# - En adoptados, hay muchos más vacunados que no
#
# Sin embargo, al realizar el test de Chi2, es necesario aceptar H1, dado que el p-valor tiene un valor muy inferior a 0.05. De modo que hay relación estadísticamente significativa entre ambas variables.

# %% [markdown]
# ***

# %%
plot_categorical_relationship_fin(train, "target", "HealthCondition")

# %%
tabla_contingencia = pd.crosstab(train["target"], train["HealthCondition"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 100.99151441002809
#
# P-Value: 9.237834745710939e-24
#
# Grados de Libertad: 1

# %% [markdown]
# p-value <<<<< 0.05, se acepta H1 --> Relación estadísticamente significativa

# %% [markdown]
# ***

# %%
plot_categorical_relationship_fin(train, "target", "PreviousOwner")

# %%
tabla_contingencia = pd.crosstab(train["target"], train["PreviousOwner"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 1.8721821158903875
#
# P-Value: 0.17122536819573866
#
# Grados de Libertad: 1

# %% [markdown]
# - Patrones parecidos entre adoptados y no adoptados
# - Sin dueño previo tiene muchos más individuos tanto en no adoptados, como en adoptados
# - Se observa que las columnas de dueño previo, muestran el número de individuos de cada columna, no la adopción.
#
# Queda confirmado por el p-value obtenido (p-value >>>>>> 0.05, no se puede rechazar H0)

# %% [markdown]
# ***

# %% [markdown]
# ### Correlación de las variables categóricas entre sí

# %%
tricategorical_analysis(train, "PetType", ["Breed", "Size"])
# Out:
# Respuesta Cat:
# Respuesta Bird:
# Respuesta Dog:
# Respuesta Rabbit:

# %%
tabla_contingencia = pd.crosstab(train["Breed"], train["Size"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 8.141205466708668
#
# P-Value: 0.7740005582383317
#
# Grados de Libertad: 12

# %% [markdown]
# Desde mi punto de vista, estas tres variables están muy poco correladas entre sí. Siguen patrones muy similares y ningún color destaca por encima de otro. Variables independientes entre sí. Confirmado por el p-value

# %%
tricategorical_analysis(train, "PetType", ["Breed", "Vaccinated"])
# Out:
# Respuesta Cat:
# Respuesta Bird:
# Respuesta Dog:
# Respuesta Rabbit:

# %%
tabla_contingencia = pd.crosstab(train["Breed"], train["Vaccinated"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 4.75386647307894
#
# P-Value: 0.5757467593950869
#
# Grados de Libertad: 6

# %% [markdown]
# Desde mi punto de vista, no veo que estén correladas entre sí. Yo creo que están vacunadas o no vacunadas, pero no que haya correlación entre la raza y la vacunación. Confirmado por p-value

# %%
tricategorical_analysis(train, "PetType", ["Breed", "HealthCondition"])
# Out:
# Respuesta Cat:
# Respuesta Bird:
# Respuesta Dog:
# Respuesta Rabbit:

# %%
tabla_contingencia = pd.crosstab(train["Breed"], train["HealthCondition"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 4.266881884118574
#
# P-Value: 0.6406096902226537
#
# Grados de Libertad: 6

# %% [markdown]
# Variable igual que la anterior: Son independientes entre sí. Yo creo que están sanos o no, pero no que haya correlación entre la raza y la vacunación. Confirmado por p-value

# %%
tricategorical_analysis(train, "PetType", ["Size", "Vaccinated"])
# Out:
# Respuesta Cat:
# Respuesta Bird:
# Respuesta Dog:
# Respuesta Rabbit:

# %%
tabla_contingencia = pd.crosstab(train["Size"], train["Vaccinated"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 0.43691131362627933
#
# P-Value: 0.8037591198952889
#
# Grados de Libertad: 2

# %% [markdown]
# Variables independientes, confirmado por p-valor

# %%
tricategorical_analysis(train, "PetType", ["Size", "HealthCondition"])
# Out:
# Respuesta Cat:
# Respuesta Bird:
# Respuesta Dog:
# Respuesta Rabbit:

# %%
tabla_contingencia = pd.crosstab(train["Size"], train["HealthCondition"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 0.3467053463078754
#
# P-Value: 0.8408410204926072
#
# Grados de Libertad: 2

# %% [markdown]
# Igual que en las variables anteriores, se confirma independencia de las variables. Confirmado por p-value

# %%
tricategorical_analysis(train, "PetType", ["Vaccinated", "HealthCondition"])
# Out:
# Respuesta Cat:
# Respuesta Bird:
# Respuesta Dog:
# Respuesta Rabbit:

# %%
tabla_contingencia = pd.crosstab(train["Vaccinated"], train["HealthCondition"])

chi2, p, dof, expected = chi2_contingency(tabla_contingencia)

print("Valor Chi-Cuadrado:", chi2, "\n")
print("P-Value:", p, "\n")
print("Grados de Libertad:", dof, "\n")
# Out:
# Valor Chi-Cuadrado: 1.2213186027543734
#
# P-Value: 0.2691020308601109
#
# Grados de Libertad: 1

# %% [markdown]
# Igual que en las variables anteriores, se confirma independencia de las variables. Confirmado por p-value

# %% [markdown]
# ##### Todas las variables categóricas son independientes entre sí. Variables correctas para la realización de los modelos

# %% [markdown]
# ***

# %% [markdown]
# ### Correlación de variables numéricas con la target gráficamente

# %%
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_ind

# %% [markdown]
# Hipótesis H0 -> No hay diferencia estadística significativa entre las medianas de los valores.
#
# Hipótesis H1 -> Hay confianza estadística en que las medianas de cada grupo son diferentes para cada valor y hay relación entre los valores de la categórica y los de la numérica.
#
# Para todas las variables!!!

# %%
plot_categorical_numerical_relationship(train, "target", "AgeYears")

# %%
grupo_a = train.loc[train.target == 1]["AgeYears"]
grupo_b = train.loc[train.target == 0]["AgeYears"]

# %%
u_stat, p_valor = mannwhitneyu(grupo_a, grupo_b)

print("Estadístico U:", u_stat)
print("Valor p:", p_valor)
# Out:
# Estadístico U: 212740.5
# Valor p: 2.873376499061277e-16

# %% [markdown]
# p-value <<<<< 0.05, se acepta H1 --> Confianza estadística, relación entre los valores de la variable categórica y la numérica

# %% [markdown]
# ***

# %%
t_stat, p_value = ttest_ind(grupo_a, grupo_b, equal_var=False)  
print(t_stat, p_value)
# Out:
# -8.125592357847411 1.42438542167769e-15

# %% [markdown]
# p-value <<<< 0.05 -> La media de AgeYears es distinta entre adoptados y no adoptados

# %% [markdown]
# ***

# %%
plot_categorical_numerical_relationship(train, "target", "WeightKg")

# %%
grupo_a = train.loc[train.target == 1]["WeightKg"]
grupo_b = train.loc[train.target == 0]["WeightKg"]

# %%
u_stat, p_valor = mannwhitneyu(grupo_a, grupo_b)

print("Estadístico U:", u_stat)
print("Valor p:", p_valor)
# Out:
# Estadístico U: 298168.0
# Valor p: 0.10550998484374101

# %% [markdown]
# p-value >>>>> 0.05, se acepta H0 --> No hay diferencia estadística, sin relación entre los valores de la variable categórica y la numérica

# %% [markdown]
# ***

# %%
t_stat, p_value = ttest_ind(grupo_a, grupo_b, equal_var=False)  
print(t_stat, p_value)
# Out:
# 1.5796530837998457 0.1144986588779481

# %% [markdown]
# p-value >>>>> 0.05 -> La media de WeightKg no es distinta entre adoptados y no adoptados

# %% [markdown]
# ***

# %%
plot_categorical_numerical_relationship(train, "target", "AdoptionFee")

# %%
grupo_a = train.loc[train.target == 1]["AdoptionFee"]
grupo_b = train.loc[train.target == 0]["AdoptionFee"]

# %%
u_stat, p_valor = mannwhitneyu(grupo_a, grupo_b)

print("Estadístico U:", u_stat)
print("Valor p:", p_valor)
# Out:
# Estadístico U: 280783.0
# Valor p: 0.7076894304193908

# %% [markdown]
# p-value >>>>> 0.05, se acepta H0 --> No hay diferencia estadística, sin relación entre los valores de la variable categórica y la numérica

# %% [markdown]
# ***

# %%
t_stat, p_value = ttest_ind(grupo_a, grupo_b, equal_var=False)  
print(t_stat, p_value)
# Out:
# -0.4106030911480871 0.6814449059010482

# %% [markdown]
# p-value >>>>> 0.05 -> La media de AdoptionFee no es distinta entre adoptados y no adoptados

# %% [markdown]
# ***

# %%
plot_categorical_numerical_relationship(train, "target", "TimeInShelterDays")

# %%
grupo_a = train.loc[train.target == 1]["TimeInShelterDays"]
grupo_b = train.loc[train.target == 0]["TimeInShelterDays"]

# %%
u_stat, p_valor = mannwhitneyu(grupo_a, grupo_b)

print("Estadístico U:", u_stat)
print("Valor p:", p_valor)
# Out:
# Estadístico U: 281561.5
# Valor p: 0.7751080563840878

# %% [markdown]
# p-value >>>>> 0.05, se acepta H0 --> No hay diferencia estadística, sin relación entre los valores de la variable categórica y la numérica

# %% [markdown]
# ***

# %%
t_stat, p_value = ttest_ind(grupo_a, grupo_b, equal_var=False)  
print(t_stat, p_value)
# Out:
# -0.33265290987813867 0.7394637739678324

# %% [markdown]
# p-value >>>>> 0.05 -> La media de AdoptionFee no es distinta entre adoptados y no adoptados

# %% [markdown]
# ***

# %% [markdown]
# ### Correlación entre variables numéricas (colinealidad)

# %%
numericas = ["WeightKg", "TimeInShelterDays", "AdoptionFee", "AgeYears"]

# %%
df_adop_num = train[numericas]

# %%
corr = df_adop_num.corr()

# %%
corr
# Out:
#                    WeightKg  TimeInShelterDays  AdoptionFee  AgeYears
# WeightKg           1.000000          -0.009129     0.009277 -0.044874
# TimeInShelterDays -0.009129           1.000000    -0.006191  0.020832
# AdoptionFee        0.009277          -0.006191     1.000000 -0.033699
# AgeYears          -0.044874           0.020832    -0.033699  1.000000

# %%
plt.figure(figsize = (9,8))
sns.heatmap(corr, annot = True, cmap = "coolwarm", center = 0)
plt.show()

# %% [markdown]
# ##### La matriz de correlación entre las variables numéricas indica que no hay correlación entre ellas. Ninguna ce las correlaciones se aproxima al 1 ni al -1, por lo que se puede determinar que las variables numéricas son independientes entre ellas, por lo que son ideales para la elaboración de un modelo.
